# %% [markdown]
# # 01 Data Generation
#
# Run the synthetic data generator and inspect row counts.

# %%
from src.generate_data import generate_dataset
tables = generate_dataset(n_users=10_000, seed=42)
{name: len(df) for name, df in tables.items()}
