# %% [markdown]
# # 03 Retention & Funnel Analysis
#
# Compute cohort retention and activation-to-paid funnel metrics.

# %%
from pathlib import Path
from src.data_cleaning import load_all_tables
from src.metrics import activation_funnel, retention_summary
tables = load_all_tables(Path('data/database/ai_product_analytics.duckdb'))
activation_funnel(tables['users'], tables['events'], tables['conversations'])
